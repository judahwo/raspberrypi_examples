# %% [markdown]
# # **`binCount.py`**
#
# This program counts from 0 to 31 in binary using 5 LEDs.  The LEDs are connected to GPIO pins 37, 35, 33, 31, and 29.  The LEDs are connected to ground through 330 ohm resistors.  The LEDs are connected to the Raspberry Pi using a breadboard. The LEDs are connected to the Raspberry Pi using the following GPIO pins:
#
# | LED | GPIO Pin |
# |-----|----------|
# | LED1 | 37 |
# | LED2 | 35 |
# | LED3 | 33 |
# | LED4 | 31 |
# | LED5 | 29 |
#
# The program uses the following steps to count from 0 to 31 in binary:
#
# | Code Example           | Code Explanation                                                       |
# |------------------------|------------------------------------------------------------------------|
# | `import RPi.GPIO as GPIO` | Import the RPi.GPIO library and alias it as GPIO.                       |
# | `import time`          | Import the time library to introduce sleep functionality.               |
# | `GPIO.setmode(GPIO.BOARD)` | Set the GPIO numbering scheme to BOARD, based on physical numbering.    |
# | `LED1=37`              | Declare variable LED1 and assign it the GPIO pin number 37.             |
# | `LED2=35`              | Declare variable LED2 and assign it the GPIO pin number 35.             |
# | `LED3=33`              | Declare variable LED3 and assign it the GPIO pin number 33.             |
# | `LED4=31`              | Declare variable LED4 and assign it the GPIO pin number 31.             |
# | `LED5=29`              | Declare variable LED5 and assign it the GPIO pin number 29.             |
# | `ON=1`                 | Declare a constant ON with the value 1 to represent the ON state.       |
# | `OFF=0`                | Declare a constant OFF with the value 0 to represent the OFF state.     |
# | `GPIO.setup(LED1,GPIO.OUT)` | Configure the GPIO pin associated with LED1 as an output pin.        |
# | `GPIO.setup(LED2,GPIO.OUT)` | Configure the GPIO pin associated with LED2 as an output pin.        |
# | `GPIO.setup(LED3,GPIO.OUT)` | Configure the GPIO pin associated with LED3 as an output pin.        |
# | `GPIO.setup(LED4,GPIO.OUT)` | Configure the GPIO pin associated with LED4 as an output pin.        |
# | `GPIO.setup(LED5,GPIO.OUT)` | Configure the GPIO pin associated with LED5 as an output pin.        |
# | `GPIO.output(LED1,0)`  | Set the GPIO pin associated with LED1 to the OFF state (0).              |
# | `GPIO.output(LED2,0)`  | Set the GPIO pin associated with LED2 to the OFF state (0).              |
# | `GPIO.output(LED3,0)`  | Set the GPIO pin associated with LED3 to the OFF state (0).              |
# | `GPIO.output(LED4,0)`  | Set the GPIO pin associated with LED4 to the OFF state (0).              |
# | `GPIO.output(LED5,0)`  | Set the GPIO pin associated with LED5 to the OFF state (0).              |
# | `time.sleep(.5)`       | Pause the execution for 0.5 seconds before moving on to the next state.  |
#
#
# Code repeats for each binary number from 0 to 31.

# %%
import RPi.GPIO as GPIO
import time
GPIO.setmode(GPIO.BOARD)

LED1=37
LED2=35
LED3=33
LED4=31
LED5=29
ON=1
OFF=0

GPIO.setup(LED1,GPIO.OUT)
GPIO.setup(LED2,GPIO.OUT)
GPIO.setup(LED3,GPIO.OUT)
GPIO.setup(LED4,GPIO.OUT)
GPIO.setup(LED5,GPIO.OUT)

GPIO.output(LED1,0)
GPIO.output(LED2,0)
GPIO.output(LED3,0)
GPIO.output(LED4,0)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,0)
GPIO.output(LED3,0)
GPIO.output(LED4,0)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,1)
GPIO.output(LED3,0)
GPIO.output(LED4,0)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,1)
GPIO.output(LED3,0)
GPIO.output(LED4,0)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,0)
GPIO.output(LED3,1)
GPIO.output(LED4,0)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,0)
GPIO.output(LED3,1)
GPIO.output(LED4,0)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,1)
GPIO.output(LED3,1)
GPIO.output(LED4,0)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,1)
GPIO.output(LED3,1)
GPIO.output(LED4,0)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,0)
GPIO.output(LED3,0)
GPIO.output(LED4,1)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,0)
GPIO.output(LED3,0)
GPIO.output(LED4,1)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,1)
GPIO.output(LED3,0)
GPIO.output(LED4,1)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,1)
GPIO.output(LED3,0)
GPIO.output(LED4,1)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,0)
GPIO.output(LED3,1)
GPIO.output(LED4,1)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,0)
GPIO.output(LED3,1)
GPIO.output(LED4,1)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,1)
GPIO.output(LED3,1)
GPIO.output(LED4,1)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,1)
GPIO.output(LED3,1)
GPIO.output(LED4,1)
GPIO.output(LED5,0)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,0)
GPIO.output(LED3,0)
GPIO.output(LED4,0)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,0)
GPIO.output(LED3,0)
GPIO.output(LED4,0)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,1)
GPIO.output(LED3,0)
GPIO.output(LED4,0)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,1)
GPIO.output(LED3,0)
GPIO.output(LED4,0)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,0)
GPIO.output(LED3,1)
GPIO.output(LED4,0)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,0)
GPIO.output(LED3,1)
GPIO.output(LED4,0)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,1)
GPIO.output(LED3,1)
GPIO.output(LED4,0)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,1)
GPIO.output(LED3,1)
GPIO.output(LED4,0)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,0)
GPIO.output(LED3,0)
GPIO.output(LED4,1)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,0)
GPIO.output(LED3,0)
GPIO.output(LED4,1)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,1)
GPIO.output(LED3,0)
GPIO.output(LED4,1)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,1)
GPIO.output(LED3,0)
GPIO.output(LED4,1)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,0)
GPIO.output(LED3,1)
GPIO.output(LED4,1)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,0)
GPIO.output(LED3,1)
GPIO.output(LED4,1)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,0)
GPIO.output(LED2,1)
GPIO.output(LED3,1)
GPIO.output(LED4,1)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.output(LED1,1)
GPIO.output(LED2,1)
GPIO.output(LED3,1)
GPIO.output(LED4,1)
GPIO.output(LED5,1)
time.sleep(.5)

GPIO.cleanup()
